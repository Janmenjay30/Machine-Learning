# %%
sentences = [
    ["i", "love", "machine", "learning"],
    ["machine", "learning", "is", "fun"],
    ["i", "love", "nlp"]
]

# %%
pip install gensim
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting gensim
#   Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from gensim) (2.2.6)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from gensim) (1.16.1)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from gensim) (7.4.3)
# Requirement already satisfied: wrapt in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.4.0-cp313-cp313-win_amd64.whl (24.4 MB)
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 1.9 MB/s eta 0:00:13
#    - -------------------------------------- 0.8/24.4 MB 1.5 MB/s eta 0:00:16
#    - -------------------------------------- 1.0/24.4 MB 1.4 MB/s eta 0:00:17
#    -- ------------------------------------- 1.3/24.4 MB 1.4 MB/s eta 0:00:17
#    -- ------------------------------------- 1.6/24.4 MB 1.4 MB/s eta 0:00:17
#    --- ------------------------------------ 1.8/24.4 MB 1.4 MB/s eta 0:00:17
#    --- ------------------------------------ 2.1/24.4 MB 1.4 MB/s eta 0:00:17
#    --- ------------------------------------ 2.4/24.4 MB 1.3 MB/s eta 0:00:17
#    ---- ----------------------------------- 2.6/24.4 MB 1.3 MB/s eta 0:00:17
#    ---- ----------------------------------- 2.9/24.4 MB 1.3 MB/s eta 0:00:17
#    ----- ---------------------------------- 3.1/24.4 MB 1.3 MB/s eta 0:00:17
#    ----- ---------------------------------- 3.4/24.4 MB 1.3 MB/s eta 0:00:17
#    ------ --------------------------------- 3.7/24.4 MB 1.3 MB/s eta 0:00:16
#    ------ --------------------------------- 3.9/24.4 MB 1.3 MB/s eta 0:00:16
#    ------ --------------------------------- 4.2/24.4 MB 1.3 MB/s eta 0:00:16
#    ------ --------------------------------- 4.2/24.4 MB 1.3 MB/s eta 0:00:16
#    ------- -------------------------------- 4.5/24.4 MB 1.2 MB/s eta 0:00:17
#    ------- -------------------------------- 4.7/24.4 MB 1.2 MB/s eta 0:00:17
#    -------- ------------------------------- 5.0/24.4 MB 1.2 MB/s eta 0:00:17
#    -------- ------------------------------- 5.2/24.4 MB 1.2 MB/s eta 0:00:16
#    --------- ------------------------------ 5.5/24.4 MB 1.2 MB/s eta 0:00:16
#    --------- ------------------------------ 5.8/24.4 MB 1.2 MB/s eta 0:00:16
#    --------- ------------------------------ 6.0/24.4 MB 1.2 MB/s eta 0:00:16
#    ---------- ----------------------------- 6.3/24.4 MB 1.2 MB/s eta 0:00:15
#    ---------- ----------------------------- 6.6/24.4 MB 1.2 MB/s eta 0:00:15
#    ----------- ---------------------------- 6.8/24.4 MB 1.2 MB/s eta 0:00:15
#    ----------- ---------------------------- 7.1/24.4 MB 1.2 MB/s eta 0:00:15
#    ------------ --------------------------- 7.3/24.4 MB 1.2 MB/s eta 0:00:14
#    ------------ --------------------------- 7.6/24.4 MB 1.2 MB/s eta 0:00:14
#    ------------ --------------------------- 7.9/24.4 MB 1.2 MB/s eta 0:00:14
#    ------------- -------------------------- 8.1/24.4 MB 1.2 MB/s eta 0:00:14
#    ------------- -------------------------- 8.4/24.4 MB 1.2 MB/s eta 0:00:13
#    -------------- ------------------------- 8.7/24.4 MB 1.2 MB/s eta 0:00:13
#    -------------- ------------------------- 8.9/24.4 MB 1.2 MB/s eta 0:00:13
#    --------------- ------------------------ 9.2/24.4 MB 1.2 MB/s eta 0:00:13
#    --------------- ------------------------ 9.4/24.4 MB 1.2 MB/s eta 0:00:13
#    --------------- ------------------------ 9.7/24.4 MB 1.2 MB/s eta 0:00:12
#    ---------------- ----------------------- 10.2/24.4 MB 1.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 10.5/24.4 MB 1.2 MB/s eta 0:00:12
#    ----------------- ---------------------- 10.7/24.4 MB 1.3 MB/s eta 0:00:11
#    ------------------ --------------------- 11.0/24.4 MB 1.3 MB/s eta 0:00:11
#    ------------------ --------------------- 11.3/24.4 MB 1.3 MB/s eta 0:00:11
#    ------------------ --------------------- 11.5/24.4 MB 1.3 MB/s eta 0:00:11
#    ------------------ --------------------- 11.5/24.4 MB 1.3 MB/s eta 0:00:11
#    ------------------- -------------------- 12.1/24.4 MB 1.3 MB/s eta 0:00:10
#    -------------------- ------------------- 12.3/24.4 MB 1.3 MB/s eta 0:00:10
#    -------------------- ------------------- 12.6/24.4 MB 1.3 MB/s eta 0:00:10
#    --------------------- ------------------ 12.8/24.4 MB 1.3 MB/s eta 0:00:10
#    --------------------- ------------------ 13.1/24.4 MB 1.3 MB/s eta 0:00:09
#    --------------------- ------------------ 13.4/24.4 MB 1.3 MB/s eta 0:00:09
#    ---------------------- ----------------- 13.6/24.4 MB 1.3 MB/s eta 0:00:09
#    ---------------------- ----------------- 13.9/24.4 MB 1.3 MB/s eta 0:00:09
#    ----------------------- ---------------- 14.2/24.4 MB 1.3 MB/s eta 0:00:09
#    ----------------------- ---------------- 14.4/24.4 MB 1.3 MB/s eta 0:00:08
#    ------------------------ --------------- 14.7/24.4 MB 1.3 MB/s eta 0:00:08
#    ------------------------ --------------- 14.9/24.4 MB 1.3 MB/s eta 0:00:08
#    ------------------------ --------------- 15.2/24.4 MB 1.3 MB/s eta 0:00:08
#    ------------------------- -------------- 15.5/24.4 MB 1.3 MB/s eta 0:00:08
#    ------------------------- -------------- 15.7/24.4 MB 1.3 MB/s eta 0:00:07
#    -------------------------- ------------- 16.0/24.4 MB 1.3 MB/s eta 0:00:07
#    -------------------------- ------------- 16.3/24.4 MB 1.3 MB/s eta 0:00:07
#    --------------------------- ------------ 16.5/24.4 MB 1.3 MB/s eta 0:00:07
#    --------------------------- ------------ 16.8/24.4 MB 1.3 MB/s eta 0:00:07
#    ---------------------------- ----------- 17.3/24.4 MB 1.3 MB/s eta 0:00:06
#    ---------------------------- ----------- 17.6/24.4 MB 1.3 MB/s eta 0:00:06
#    ----------------------------- ---------- 17.8/24.4 MB 1.3 MB/s eta 0:00:06
#    ----------------------------- ---------- 18.1/24.4 MB 1.3 MB/s eta 0:00:05
#    ------------------------------ --------- 18.4/24.4 MB 1.3 MB/s eta 0:00:05
#    ------------------------------ --------- 18.6/24.4 MB 1.3 MB/s eta 0:00:05
#    ------------------------------ --------- 18.9/24.4 MB 1.3 MB/s eta 0:00:05
#    ------------------------------- -------- 19.1/24.4 MB 1.3 MB/s eta 0:00:05
#    ------------------------------- -------- 19.4/24.4 MB 1.3 MB/s eta 0:00:04
#    -------------------------------- ------- 19.7/24.4 MB 1.3 MB/s eta 0:00:04
#    -------------------------------- ------- 19.9/24.4 MB 1.3 MB/s eta 0:00:04
#    --------------------------------- ------ 20.2/24.4 MB 1.3 MB/s eta 0:00:04
#    --------------------------------- ------ 20.4/24.4 MB 1.3 MB/s eta 0:00:04
#    --------------------------------- ------ 20.7/24.4 MB 1.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 21.0/24.4 MB 1.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 21.2/24.4 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.5/24.4 MB 1.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 21.8/24.4 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------ --- 22.0/24.4 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 22.3/24.4 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 22.5/24.4 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 23.1/24.4 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 23.3/24.4 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  23.9/24.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  24.1/24.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.4 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 24.4/24.4 MB 1.3 MB/s  0:00:19
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from gensim.models import Word2Vec

# %%
model=Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=1,
    workers=4,sg=1
)

# %%
model.wv["machine"]
# Out:
# array([-8.6196875e-03,  3.6657380e-03,  5.1898835e-03,  5.7419385e-03,
#         7.4669183e-03, -6.1676754e-03,  1.1056137e-03,  6.0472824e-03,
#        -2.8400505e-03, -6.1735227e-03, -4.1022300e-04, -8.3689485e-03,
#        -5.6000124e-03,  7.1045388e-03,  3.3525396e-03,  7.2256695e-03,
#         6.8002474e-03,  7.5307419e-03, -3.7891543e-03, -5.6180597e-04,
#         2.3483764e-03, -4.5190323e-03,  8.3887316e-03, -9.8581640e-03,
#         6.7646410e-03,  2.9144168e-03, -4.9328315e-03,  4.3981876e-03,
#        -1.7395747e-03,  6.7113843e-03,  9.9648498e-03, -4.3624435e-03,
#        -5.9933780e-04, -5.6956373e-03,  3.8508223e-03,  2.7866268e-03,
#         6.8910765e-03,  6.1010956e-03,  9.5384968e-03,  9.2734173e-03,
#         7.8980681e-03, -6.9895042e-03, -9.1558648e-03, -3.5575271e-04,
#        -3.0998408e-03,  7.8943167e-03,  5.9385742e-03, -1.5456629e-03,
#         1.5109634e-03,  1.7900408e-03,  7.8175711e-03, -9.5101865e-03,
#        -2.0553112e-04,  3.4691966e-03, -9.3897223e-04,  8.3817719e-03,
#         9.0107834e-03,  6.5365066e-03, -7.1162102e-04,  7.7104042e-03,
#        -8.5343346e-03,  3.2071066e-03, -4.6379971e-03, -5.0889552e-03,
#         3.5896183e-03,  5.3703394e-03,  7.7695143e-03, -5.7665063e-03,
#         7.4333609e-03,  6.6254963e-03, -3.7098003e-03, -8.7456414e-03,
#         5.4374672e-03,  6.5097557e-03, -7.8755023e-04, -6.7098560e-03,
#        -7.0859254e-03, -2.4970602e-03,  5.1432536e-03, -3.6652375e-03,
#        -9.3700597e-03,  3.8267397e-03,  4.8844791e-03, -6.4285635e-03,
#         1.2085581e-03, -2.0748770e-03,  2.4403334e-05, -9.8835090e-03,
#         2.6920044e-03, -4.7501065e-03,  1.0876465e-03, -1.5762246e-03,
#         2.1966731e-03, -7.8815762e-03, -2.7171839e-03,  2.6631986e-03,
#         5.3466819e-03, -2.3915148e-03, -9.5100943e-03,  4.5058788e-03],
#       dtype=float32)

# %%
from gensim.models import KeyedVectors

# %%
import gensim.downloader as api

wv=api.load('word2vec-google-news-300')

print(wv.most_similar('king'))
# Out:
# [==================--------------------------------] 36.8% 612.2/1662.8MB downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import gensim.downloader as api
# ----> 3 wv=api.load('word2vec-google-news-300')
#       5 print(wv.most_similar('king'))
#
# File c:\Users\janme\AppData\Local\Programs\Python\Python313\Lib\site-packages\gensim\downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File c:\Users\janme\AppData\Local\Programs\Python\Python313\Lib\site-packages\gensim\downloader.py:396, in _download(name)
#     394 fname = "{fname}.gz".format(fname=name)
#     395 dst_path = os.path.join(tmp_dir, fname)
# --> 396 urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
#     397 if _calculate_md5_checksum(dst_path) == _get_checksum(name):
#     398     sys.stdout.write("\n")
#
# File c:\Users\janme\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:247, in urlretrieve(url, filename, reporthook, data)
#     245             blocknum += 1
#     246             if reporthook:
# --> 247                 reporthook(blocknum, bs, size)
#     249 if size >= 0 and read < size:
#     250     raise ContentTooShortError(
#     251         "retrieval incomplete: got only %i out of %i bytes"
#     252         % (read, size), result)
#
# File c:\Users\janme\AppData\Local\Programs\Python\Python313\Lib\site-packages\gensim\downloader.py:129, in _progress(chunks_downloaded, chunk_size, total_size, part, total_parts)
#     122 if total_parts == 1:
#     123     sys.stdout.write(
#     124         '\r[%s] %s%s %s/%sMB downloaded' % (
#     125             bar, percent_downloaded, "%",
#     126             round(size_downloaded / (1024 * 1024), 1),
#     127             round(float(total_size) / (1024 * 1024), 1))
#     128     )
# --> 129     sys.stdout.flush()
#     130 else:
#     131     sys.stdout.write(
#     132         '\r Part %s/%s [%s] %s%s %s/%sMB downloaded' % (
#     133             part + 1, total_parts, bar, percent_downloaded, "%",
#     134             round(size_downloaded / (1024 * 1024), 1),
#     135             round(float(total_size) / (1024 * 1024), 1))
#     136     )
#
# File c:\Users\janme\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\iostream.py:604, in OutStream.flush(self)
#     602     self.pub_thread.schedule(evt.set)
#     603     # and give a timeout to avoid
# --> 604     if not evt.wait(self.flush_timeout):
#     605         # write directly to __stderr__ instead of warning because
#     606         # if this is happening sys.stderr may be the problem.
#     607         print("IOStream.flush timed out", file=sys.__stderr__)
#     608 else:
#
# File c:\Users\janme\AppData\Local\Programs\Python\Python313\Lib\threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File c:\Users\janme\AppData\Local\Programs\Python\Python313\Lib\threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
