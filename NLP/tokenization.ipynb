# %%
print("Hello, Machine Learning!")
# Out:
# Hello, Machine Learning!

# %%
corpus='''Hello welcom
to janmenjay class'''

# %%
print(corpus)
# Out:
# Hello welcom
# to janmenjay class

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\janme\appdata\local\programs\python\python313\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from nltk.tokenize import sent_tokenize


print(corpus)
# Out:
# Hello welcom
# to janmenjay class

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\janme\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
sentences=sent_tokenize(corpus)
print(sentences)
# Out:
# ['Hello welcom\nto janmenjay class']
